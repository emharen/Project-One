# %%
#Dependencies
import pandas as pd
from sodapy import Socrata
from SocrataKeys import (MyAppToken, username, password)

# %%
#Pull the dataset
client = Socrata("data.cityofchicago.org", None)

#Endpoints
    #85ca-t3if = Vehicle Crashes
    #x3ag-h7gt = Red Light Camera Locations
    #twfh-866z = Red Light Violations
    #3v4z-xnbf = Speed Camera Violations
    #5qvk-gt8i = Speed Camera Locations
    
#Can also (theoretically) pass in MyAppToken, password, and username as arguments
results = client.get("85ca-t3if", None)


results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-b105ee662e8c> in <module>
#      10
#      11 #Can also (theoretically) pass in MyAppToken, password, and username as arguments
# ---> 12 results = client.get("85ca-t3if", None)
#      13
#      14
#
# ~\Anaconda3\envs\DataClass\lib\site-packages\sodapy\__init__.py in get(self, dataset_identifier, content_type, **kwargs)
#     338             http://dev.socrata.com/docs/system-fields.html
#     339         '''
# --> 340         resource = _format_new_api_request(dataid=dataset_identifier, content_type=content_type)
#     341         headers = _clear_empty_values({"Accept": kwargs.pop("format", None)})
#     342
#
# ~\Anaconda3\envs\DataClass\lib\site-packages\sodapy\__init__.py in _format_new_api_request(dataid, row_id, content_type)
#     565                 return "{0}{1}.{2}".format(DEFAULT_API_PATH, dataid, content_type)
#     566
# --> 567     raise Exception("This method requires at least a dataset_id or content_type.")
#     568
#     569
#
# Exception: This method requires at least a dataset_id or content_type.

# %%
# Out:
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                          17                       22535
# 1                          38                       21849
# 2                          17                       22615
# 3                           7                       22254
# 4                          44                       22615
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                           7                          71
# 1                          28                         748
# 2                           7                         306
# 3                          39                         396
# 4                          52                          77
#
#   :@computed_region_vrxf_vc4k first_approach             go_live_date  \
# 0                          22             SB  2009-05-15T00:00:00.000
# 1                          13             SB  2007-10-18T00:00:00.000
# 2                          19             SB  2006-02-25T00:00:00.000
# 3                          17             NB  2007-06-18T00:00:00.000
# 4                          19             EB  2008-11-14T00:00:00.000
#
#              intersection   latitude  \
# 0        Pulaski-Diversey  41.931791
# 1          Pulaski-Foster  41.975532
# 2        Cicero-Fullerton  41.924237
# 3          Harlem-Belmont  41.937997
# 4  Narragansett-Fullerton  41.923676
#
#                                             location   longitude  \
# 0  {'type': 'Point', 'coordinates': [-87.726979, ...  -87.726979
# 1  {'type': 'Point', 'coordinates': [-87.728234, ...  -87.728234
# 2  {'type': 'Point', 'coordinates': [-87.746302, ...  -87.746302
# 3  {'type': 'Point', 'coordinates': [-87.806746, ...  -87.806746
# 4  {'type': 'Point', 'coordinates': [-87.785441, ...  -87.785441
#
#   second_approach third_approach
# 0              NB            NaN
# 1              WB            NaN
# 2              WB            NaN
# 3              WB            NaN
# 4              WB            NaN
